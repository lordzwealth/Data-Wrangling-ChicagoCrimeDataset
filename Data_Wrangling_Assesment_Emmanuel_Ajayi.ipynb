# %% [markdown]
# <a href="https://colab.research.google.com/github/lordzwealth/Data-Wrangling-ChicagoCrimeDataset/blob/main/Data_Wrangling_Assesment_Emmanuel_Ajayi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Using the Chicago Crime Dataset(any of the 3 sheets you choose), perfrom the following data preparation steps:
# 1. Use a funtion to Drop redundant columns (a redundant colum is one that gives infromation that another column already explains: eg ID and Case number)
# 2. Use functions to create new columns for Months, Day, Season.
# 3. Use subsetting and grouping to show how the frequency of crime is distributed within Months, Days, Seasons with the most crime record and what crimes are highest and lowest?
# 4.  According to location description, where does crime hapen the most?
# 5.  Did the Types of crime change as years go by? if yes/no. let the data show the insight.

# %%
# Importing necessary libraries
import pandas as pd

# Loading the Chicago Crime Dataset
file = '/content/chicago1.csv'
df = pd.read_csv(file).drop('Unnamed: 0', axis=1)

# make index start from 1
df.index = df.index + 1

# %%
df.head()
# Out:
#          ID Case Number                    Date                 Block  IUCR  \
# 1   6407111    HP485721  07/26/2008 02:30:00 PM  085XX S MUSKEGON AVE  1320
# 2  11398199    JB372830  07/31/2018 10:57:00 AM     092XX S ELLIS AVE  143C
# 3   5488785    HN308568  04/27/2007 10:30:00 AM     062XX N TRIPP AVE  0610
# 4  11389116    JB361368  07/23/2018 08:55:00 AM    0000X N KEELER AVE  0560
# 5  12420431    JE297624  07/11/2021 06:40:00 AM   016XX W HARRISON ST  051A
#
#         Primary Type               Description  \
# 1    CRIMINAL DAMAGE                TO VEHICLE
# 2  WEAPONS VIOLATION  UNLAWFUL POSS AMMUNITION
# 3           BURGLARY            FORCIBLE ENTRY
# 4            ASSAULT                    SIMPLE
# 5            ASSAULT      AGGRAVATED - HANDGUN
#
#                      Location Description  Arrest  Domestic  ...  Ward  \
# 1                                  STREET   False     False  ...  10.0
# 2                               POOL ROOM    True     False  ...   8.0
# 3                               RESIDENCE    True     False  ...  39.0
# 4            NURSING HOME/RETIREMENT HOME   False     False  ...  28.0
# 5  PARKING LOT / GARAGE (NON RESIDENTIAL)   False     False  ...  27.0
#
#    Community Area  FBI Code  X Coordinate Y Coordinate  Year  \
# 1            46.0        14     1196638.0    1848800.0  2008
# 2            47.0        15     1184499.0    1843935.0  2018
# 3            12.0        05     1146911.0    1941022.0  2007
# 4            26.0       08A     1148388.0    1899882.0  2018
# 5            28.0       04A     1165430.0    1897441.0  2021
#
#                Updated On   Latitude  Longitude                       Location
# 1  02/28/2018 03:56:25 PM  41.739980 -87.555120  (41.739979622, -87.555120042)
# 2  08/07/2018 04:02:59 PM  41.726922 -87.599747  (41.726922145, -87.599746995)
# 3  02/28/2018 03:56:25 PM  41.994138 -87.734959  (41.994137622, -87.734959049)
# 4  07/30/2018 03:52:24 PM  41.881217 -87.730590  (41.881217483, -87.730589961)
# 5  07/18/2021 04:56:02 PM  41.874174 -87.668082  (41.874173691, -87.668082118)
#
# [5 rows x 22 columns]

# %%
df.isnull().sum()
# Out:
# ID                       0
# Case Number              0
# Date                     0
# Block                    0
# IUCR                     0
# Primary Type             0
# Description              0
# Location Description     1
# Arrest                   0
# Domestic                 0
# Beat                     0
# District                 0
# Ward                    81
# Community Area          81
# FBI Code                 0
# X Coordinate             8
# Y Coordinate             8
# Year                     0
# Updated On               0
# Latitude                 8
# Longitude                8
# Location                 8
# dtype: int64

# %%
# Filling Missing Values with the Median (Ward & Community Area)
df['Ward'] = df['Ward'].fillna(df['Ward'].median())

# %%
df['Community Area'] = df['Community Area'].fillna(df['Community Area'].median())

# %%
df.isnull().sum()
# Out:
# ID                      0
# Case Number             0
# Date                    0
# Block                   0
# IUCR                    0
# Primary Type            0
# Description             0
# Location Description    1
# Arrest                  0
# Domestic                0
# Beat                    0
# District                0
# Ward                    0
# Community Area          0
# FBI Code                0
# X Coordinate            8
# Y Coordinate            8
# Year                    0
# Updated On              0
# Latitude                8
# Longitude               8
# Location                8
# dtype: int64

# %% [markdown]
# 1.   Use a funtion to Drop redundant columns (a redundant colum is one that gives infromation that another column already explains: eg ID and Case number)

# %%
def drop_columns(df, columns):
    for column in columns:
        if column in df.columns:
            df.drop(columns=[column], inplace=True)
        else:
            print(f"Column '{column}' not found in the dataframe.")
    return df

# %%
drop_columns(df, ['ID', 'Latitude', 'Longitude', 'col1'])
# Out:
# Column 'col1' not found in the dataframe.
#      Case Number                    Date                   Block  IUCR  \
# 1       HP485721  07/26/2008 02:30:00 PM    085XX S MUSKEGON AVE  1320
# 2       JB372830  07/31/2018 10:57:00 AM       092XX S ELLIS AVE  143C
# 3       HN308568  04/27/2007 10:30:00 AM       062XX N TRIPP AVE  0610
# 4       JB361368  07/23/2018 08:55:00 AM      0000X N KEELER AVE  0560
# 5       JE297624  07/11/2021 06:40:00 AM     016XX W HARRISON ST  051A
# ...          ...                     ...                     ...   ...
# 996     HN325328  05/06/2007 02:08:51 AM    080XX S MUSKEGON AVE  1310
# 997     HT181792  02/27/2011 06:00:00 PM  052XX S BLACKSTONE AVE  0486
# 998     HL263341  03/29/2005 05:30:00 PM      003XX S WABASH AVE  0810
# 999     HR401314  06/29/2009 11:00:00 PM     068XX S CHAPPEL AVE  0486
# 1000    HM578375  09/02/2006 10:26:29 PM        024XX S STATE ST  1811
#
#            Primary Type                   Description  \
# 1       CRIMINAL DAMAGE                    TO VEHICLE
# 2     WEAPONS VIOLATION      UNLAWFUL POSS AMMUNITION
# 3              BURGLARY                FORCIBLE ENTRY
# 4               ASSAULT                        SIMPLE
# 5               ASSAULT          AGGRAVATED - HANDGUN
# ...                 ...                           ...
# 996     CRIMINAL DAMAGE                   TO PROPERTY
# 997             BATTERY       DOMESTIC BATTERY SIMPLE
# 998               THEFT                     OVER $500
# 999             BATTERY       DOMESTIC BATTERY SIMPLE
# 1000          NARCOTICS  POSS: CANNABIS 30GMS OR LESS
#
#                         Location Description  Arrest  Domestic  Beat  \
# 1                                     STREET   False     False   423
# 2                                  POOL ROOM    True     False   413
# 3                                  RESIDENCE    True     False  1711
# 4               NURSING HOME/RETIREMENT HOME   False     False  1115
# 5     PARKING LOT / GARAGE (NON RESIDENTIAL)   False     False  1231
# ...                                      ...     ...       ...   ...
# 996                                RESIDENCE   False     False   422
# 997                                   STREET   False     False  2131
# 998           PARKING LOT/GARAGE(NON.RESID.)   False     False   123
# 999                                APARTMENT    True      True   331
# 1000                 CHA PARKING LOT/GROUNDS    True     False   134
#
#       District  Ward  Community Area FBI Code  X Coordinate  Y Coordinate  \
# 1          4.0  10.0            46.0       14     1196638.0     1848800.0
# 2          4.0   8.0            47.0       15     1184499.0     1843935.0
# 3         17.0  39.0            12.0       05     1146911.0     1941022.0
# 4         11.0  28.0            26.0      08A     1148388.0     1899882.0
# 5         12.0  27.0            28.0      04A     1165430.0     1897441.0
# ...        ...   ...             ...      ...           ...           ...
# 996        4.0   7.0            46.0       14     1196565.0     1852179.0
# 997        2.0   4.0            41.0      08B     1186800.0     1870814.0
# 998        1.0   2.0            32.0       06     1176860.0     1898834.0
# 999        3.0   5.0            43.0      08B     1191056.0     1860048.0
# 1000       1.0   3.0            33.0       18     1176702.0     1888138.0
#
#       Year              Updated On                       Location
# 1     2008  02/28/2018 03:56:25 PM  (41.739979622, -87.555120042)
# 2     2018  08/07/2018 04:02:59 PM  (41.726922145, -87.599746995)
# 3     2007  02/28/2018 03:56:25 PM  (41.994137622, -87.734959049)
# 4     2018  07/30/2018 03:52:24 PM  (41.881217483, -87.730589961)
# 5     2021  07/18/2021 04:56:02 PM  (41.874173691, -87.668082118)
# ...    ...                     ...                            ...
# 996   2007  02/10/2018 03:50:01 PM   (41.74925367, -87.555275558)
# 997   2011  02/10/2018 03:50:01 PM   (41.80062644, -87.590467932)
# 998   2005  02/28/2018 03:56:25 PM  (41.877745403, -87.626074642)
# 999   2009  02/28/2018 03:56:25 PM  (41.770981786, -87.575208206)
# 1000  2006  02/28/2018 03:56:25 PM  (41.848398456, -87.626977894)
#
# [1000 rows x 19 columns]

# %%
df.columns
# Out:
# Index(['Case Number', 'Date', 'Block', 'IUCR', 'Primary Type', 'Description',
#        'Location Description', 'Arrest', 'Domestic', 'Beat', 'District',
#        'Ward', 'Community Area', 'FBI Code', 'X Coordinate', 'Y Coordinate',
#        'Year', 'Updated On', 'Location'],
#       dtype='object')

# %% [markdown]
# 2. Use functions to create new columns for Months, Day, Season.

# %%
#Creating a function for the Month Column
from datetime import datetime

def extractMonth(date):
  date_column = pd.to_datetime(date, format='%m/%d/%Y %I:%M:%S %p')
  month_names = date_column.dt.month_name()

  return month_names

# %%
df['Month'] = extractMonth(df['Date'])

# %%
df.head(4)
# Out:
#   Case Number                    Date                 Block  IUCR  \
# 1    HP485721  07/26/2008 02:30:00 PM  085XX S MUSKEGON AVE  1320
# 2    JB372830  07/31/2018 10:57:00 AM     092XX S ELLIS AVE  143C
# 3    HN308568  04/27/2007 10:30:00 AM     062XX N TRIPP AVE  0610
# 4    JB361368  07/23/2018 08:55:00 AM    0000X N KEELER AVE  0560
#
#         Primary Type               Description          Location Description  \
# 1    CRIMINAL DAMAGE                TO VEHICLE                        STREET
# 2  WEAPONS VIOLATION  UNLAWFUL POSS AMMUNITION                     POOL ROOM
# 3           BURGLARY            FORCIBLE ENTRY                     RESIDENCE
# 4            ASSAULT                    SIMPLE  NURSING HOME/RETIREMENT HOME
#
#    Arrest  Domestic  Beat  District  Ward  Community Area FBI Code  \
# 1   False     False   423       4.0  10.0            46.0       14
# 2    True     False   413       4.0   8.0            47.0       15
# 3    True     False  1711      17.0  39.0            12.0       05
# 4   False     False  1115      11.0  28.0            26.0      08A
#
#    X Coordinate  Y Coordinate  Year              Updated On  \
# 1     1196638.0     1848800.0  2008  02/28/2018 03:56:25 PM
# 2     1184499.0     1843935.0  2018  08/07/2018 04:02:59 PM
# 3     1146911.0     1941022.0  2007  02/28/2018 03:56:25 PM
# 4     1148388.0     1899882.0  2018  07/30/2018 03:52:24 PM
#
#                         Location  Month
# 1  (41.739979622, -87.555120042)   July
# 2  (41.726922145, -87.599746995)   July
# 3  (41.994137622, -87.734959049)  April
# 4  (41.881217483, -87.730589961)   July

# %%
#Creating a function for the Day Column
df['Day'] = df['Date'].apply(lambda date: pd.to_datetime(date, format='%m/%d/%Y %I:%M:%S %p').dayofweek)
df['Day'] = df['Day'].map({
    0: 'Monday',
    1: 'Tuesday',
    2: 'Wednesday',
    3: 'Thursday',
    4: 'Friday',
    5: 'Saturday',
    6: 'Sunday'
})

# %%
df.head(4)
# Out:
#   Case Number                    Date                 Block  IUCR  \
# 1    HP485721  07/26/2008 02:30:00 PM  085XX S MUSKEGON AVE  1320
# 2    JB372830  07/31/2018 10:57:00 AM     092XX S ELLIS AVE  143C
# 3    HN308568  04/27/2007 10:30:00 AM     062XX N TRIPP AVE  0610
# 4    JB361368  07/23/2018 08:55:00 AM    0000X N KEELER AVE  0560
#
#         Primary Type               Description          Location Description  \
# 1    CRIMINAL DAMAGE                TO VEHICLE                        STREET
# 2  WEAPONS VIOLATION  UNLAWFUL POSS AMMUNITION                     POOL ROOM
# 3           BURGLARY            FORCIBLE ENTRY                     RESIDENCE
# 4            ASSAULT                    SIMPLE  NURSING HOME/RETIREMENT HOME
#
#    Arrest  Domestic  Beat  ...  Ward  Community Area  FBI Code X Coordinate  \
# 1   False     False   423  ...  10.0            46.0        14    1196638.0
# 2    True     False   413  ...   8.0            47.0        15    1184499.0
# 3    True     False  1711  ...  39.0            12.0        05    1146911.0
# 4   False     False  1115  ...  28.0            26.0       08A    1148388.0
#
#    Y Coordinate  Year              Updated On                       Location  \
# 1     1848800.0  2008  02/28/2018 03:56:25 PM  (41.739979622, -87.555120042)
# 2     1843935.0  2018  08/07/2018 04:02:59 PM  (41.726922145, -87.599746995)
# 3     1941022.0  2007  02/28/2018 03:56:25 PM  (41.994137622, -87.734959049)
# 4     1899882.0  2018  07/30/2018 03:52:24 PM  (41.881217483, -87.730589961)
#
#    Month       Day
# 1   July  Saturday
# 2   July   Tuesday
# 3  April    Friday
# 4   July    Monday
#
# [4 rows x 21 columns]

# %%
# creating a column for seasons

def createSeason(date_column):
    # Ensure the input is in datetime format
    date_column = pd.to_datetime(date_column, format='%m/%d/%Y %I:%M:%S %p')

    # Define a mapping of month to season
    month_to_season = {
        1: 'Winter', 2: 'Winter', 3: 'Spring',
        4: 'Spring', 5: 'Spring', 6: 'Summer',
        7: 'Summer', 8: 'Summer', 9: 'Fall',
        10: 'Fall', 11: 'Fall', 12: 'Winter'
    }

    # Extract the month and map to season
    seasons_column = date_column.dt.month.map(month_to_season)

    return seasons_column

# %%
df['Seasons'] = createSeason(df['Date'])

# %%
df.head(10)
# Out:
#    Case Number                    Date                   Block  IUCR  \
# 1     HP485721  07/26/2008 02:30:00 PM    085XX S MUSKEGON AVE  1320
# 2     JB372830  07/31/2018 10:57:00 AM       092XX S ELLIS AVE  143C
# 3     HN308568  04/27/2007 10:30:00 AM       062XX N TRIPP AVE  0610
# 4     JB361368  07/23/2018 08:55:00 AM      0000X N KEELER AVE  0560
# 5     JE297624  07/11/2021 06:40:00 AM     016XX W HARRISON ST  051A
# 6      G498287  08/21/2001 12:00:00 AM           003XX W 28 PL  0810
# 7     HM660983  10/14/2006 10:00:00 PM     006XX S CENTRAL AVE  0320
# 8     HX527438  12/02/2014 11:48:00 AM     043XX W POTOMAC AVE  1811
# 9     HS386492  06/30/2010 01:00:00 AM      032XX W PIERCE AVE  0910
# 10    HZ313634  06/18/2016 11:15:00 PM  021XX N CALIFORNIA AVE  1811
#
#            Primary Type                   Description  \
# 1       CRIMINAL DAMAGE                    TO VEHICLE
# 2     WEAPONS VIOLATION      UNLAWFUL POSS AMMUNITION
# 3              BURGLARY                FORCIBLE ENTRY
# 4               ASSAULT                        SIMPLE
# 5               ASSAULT          AGGRAVATED - HANDGUN
# 6                 THEFT                     OVER $500
# 7               ROBBERY         STRONGARM - NO WEAPON
# 8             NARCOTICS  POSS: CANNABIS 30GMS OR LESS
# 9   MOTOR VEHICLE THEFT                    AUTOMOBILE
# 10            NARCOTICS  POSS: CANNABIS 30GMS OR LESS
#
#                       Location Description  Arrest  Domestic  Beat  ...  \
# 1                                   STREET   False     False   423  ...
# 2                                POOL ROOM    True     False   413  ...
# 3                                RESIDENCE    True     False  1711  ...
# 4             NURSING HOME/RETIREMENT HOME   False     False  1115  ...
# 5   PARKING LOT / GARAGE (NON RESIDENTIAL)   False     False  1231  ...
# 6                                   STREET   False     False  2113  ...
# 7                             CTA PLATFORM   False     False  1513  ...
# 8                                    ALLEY    True     False  2534  ...
# 9                                   STREET   False     False  1422  ...
# 10         POLICE FACILITY/VEH PARKING LOT    True     False  1414  ...
#
#     Community Area  FBI Code  X Coordinate Y Coordinate  Year  \
# 1             46.0        14     1196638.0    1848800.0  2008
# 2             47.0        15     1184499.0    1843935.0  2018
# 3             12.0        05     1146911.0    1941022.0  2007
# 4             26.0       08A     1148388.0    1899882.0  2018
# 5             28.0       04A     1165430.0    1897441.0  2021
# 6             32.0        06     1174343.0    1885951.0  2001
# 7             25.0        03     1139154.0    1896536.0  2006
# 8             23.0        18     1147306.0    1908305.0  2014
# 9             23.0        07     1154458.0    1910116.0  2010
# 10            22.0        18     1157345.0    1914452.0  2016
#
#                 Updated On                       Location     Month  \
# 1   02/28/2018 03:56:25 PM  (41.739979622, -87.555120042)      July
# 2   08/07/2018 04:02:59 PM  (41.726922145, -87.599746995)      July
# 3   02/28/2018 03:56:25 PM  (41.994137622, -87.734959049)     April
# 4   07/30/2018 03:52:24 PM  (41.881217483, -87.730589961)      July
# 5   07/18/2021 04:56:02 PM  (41.874173691, -87.668082118)      July
# 6   08/17/2015 03:03:40 PM  (41.842450075, -87.635700695)    August
# 7   02/28/2018 03:56:25 PM  (41.872208575, -87.764578577)   October
# 8   02/10/2018 03:50:01 PM  (41.904351902, -87.734347128)  December
# 9   02/10/2018 03:50:01 PM  (41.909181404, -87.708027242)      June
# 10  02/10/2018 03:50:01 PM   (41.921021491, -87.69730355)      June
#
#           Day Seasons
# 1    Saturday  Summer
# 2     Tuesday  Summer
# 3      Friday  Spring
# 4      Monday  Summer
# 5      Sunday  Summer
# 6     Tuesday  Summer
# 7    Saturday    Fall
# 8     Tuesday  Winter
# 9   Wednesday  Summer
# 10   Saturday  Summer
#
# [10 rows x 22 columns]

# %% [markdown]
# 3. Use subsetting and grouping to show how the frequency of crime is distributed within Months, Days, Seasons with the most crime record and what crimes are highest and lowest?

# %%
#Show the distribution of Crime in-respect to their Month
df.groupby('Month')['Primary Type'].value_counts()
# Out:
# Month      Primary Type
# April      THEFT                     23
#            NARCOTICS                 19
#            BATTERY                   17
#            CRIMINAL DAMAGE            9
#            BURGLARY                   7
#                                      ..
# September  MOTOR VEHICLE THEFT        3
#            OTHER OFFENSE              3
#            HOMICIDE                   1
#            PROSTITUTION               1
#            PUBLIC PEACE VIOLATION     1
# Name: Primary Type, Length: 170, dtype: int64

# %%
# Find the month with the highest crime count
crime_counts_by_month = df.groupby('Month')['Month'].count()
highest_crime_month = crime_counts_by_month.idxmax()
lowest_crime_month = crime_counts_by_month.idxmin()

print("Month with the highest crime count:", highest_crime_month)
print("Month with thw lowest crime count:", lowest_crime_month)
# Out:
# Month with the highest crime count: April
# Month with thw lowest crime count: February

# %%
#Show the distribution of Crime in-respect to their Day of the Week
df.groupby('Day')['Primary Type'].value_counts()
# Out:
# Day        Primary Type
# Friday     THEFT                               21
#            BATTERY                             20
#            NARCOTICS                           14
#            CRIMINAL DAMAGE                     13
#            BURGLARY                            11
#                                                ..
# Wednesday  WEAPONS VIOLATION                    2
#            CRIMINAL SEXUAL ASSAULT              1
#            INTERFERENCE WITH PUBLIC OFFICER     1
#            PROSTITUTION                         1
#            PUBLIC PEACE VIOLATION               1
# Name: Primary Type, Length: 116, dtype: int64

# %%
# Find the Day with the highest and lowest crime count
crime_counts_by_day = df.groupby('Day')['Day'].count()
highest_crime_day = crime_counts_by_day.idxmax()
lowest_crime_day = crime_counts_by_day.idxmin()

print("Day with the highest crime count:", highest_crime_day)
print("Day with thw lowest crime count:", lowest_crime_day)
# Out:
# Day with the highest crime count: Monday
# Day with thw lowest crime count: Friday

# %%
#Show the distribution of Crime in-respect to their Season
df.groupby('Seasons')['Primary Type'].value_counts()
# Out:
# Seasons  Primary Type
# Fall     BATTERY                       56
#          THEFT                         45
#          CRIMINAL DAMAGE               27
#          NARCOTICS                     23
#          BURGLARY                      22
#                                        ..
# Winter   OFFENSE INVOLVING CHILDREN     2
#          SEX OFFENSE                    2
#          STALKING                       2
#          PROSTITUTION                   1
#          PUBLIC PEACE VIOLATION         1
# Name: Primary Type, Length: 75, dtype: int64

# %%
# Find the Day with the highest and lowest crime count
crime_counts_by_season = df.groupby('Seasons')['Seasons'].count()
highest_crime_season = crime_counts_by_season.idxmax()
lowest_crime_season = crime_counts_by_season.idxmin()

print("Season with the highest crime count:", highest_crime_season)
print("Season with thw lowest crime count:", lowest_crime_season)
# Out:
# Season with the highest crime count: Spring
# Season with thw lowest crime count: Winter

# %% [markdown]
# 4. According to location description, where does crime hapen the most?

# %%
# Finding the Location with the highest crime occurences
df['Location Description'].value_counts()
# Out:
# STREET                               251
# RESIDENCE                            169
# APARTMENT                            113
# SIDEWALK                              98
# PARKING LOT/GARAGE(NON.RESID.)        31
#                                     ...
# RESIDENCE - YARD (FRONT / BACK)        1
# MOVIE HOUSE/THEATER                    1
# CONSTRUCTION SITE                      1
# ABANDONED BUILDING                     1
# COLLEGE/UNIVERSITY RESIDENCE HALL      1
# Name: Location Description, Length: 66, dtype: int64

# %%
# Location with the highest crime occurence
crime_counts_by_location = df.groupby('Location Description')['Location Description'].count()
highest_crime_location = crime_counts_by_location.idxmax()
print("Location with the highest crime count:", highest_crime_location)
# Out:
# Location with the highest crime count: STREET

# %% [markdown]
# 5. Did the Types of crime change as years go by? if yes/no. let the data show the insight.

# %%
# Group the data by year and crime type, count the occurrences
crime_counts_by_year = df.groupby('Year')['Primary Type'].value_counts()

# %%
crime_counts_by_year.head
# Out:
# <bound method NDFrame.head of Year  Primary Type
# 2001  CRIMINAL DAMAGE       11
#       THEFT                 11
#       BATTERY               10
#       NARCOTICS             10
#       ASSAULT                8
#                             ..
# 2022  BATTERY                2
#       DECEPTIVE PRACTICE     2
#       NARCOTICS              1
#       OTHER OFFENSE          1
#       ROBBERY                1
# Name: Primary Type, Length: 262, dtype: int64>
